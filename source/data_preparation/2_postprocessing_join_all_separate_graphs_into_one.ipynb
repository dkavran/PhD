# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

from PIL import Image, ImageEnhance
import cv2

import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import torch
import math
import _pickle as pickle
import pandas as pd
import copy
import networkx as nx

from os import listdir
from os.path import isfile, join
from natsort import natsorted
from skimage.segmentation import mark_boundaries

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,15)

# Implemented imports
import sys
sys.path.append('../')
from proposed_method_lib.graph import segment_images, plot_nx_graph, save_graphs_to_file, save_item_with_pickle, load_item_with_pickle, get_indices_and_labels_for_time_frame_without_labels
from proposed_method_lib.graph_node import create_time_series_graphs, get_nx_graph, get_nx_graph_fast, get_all_possible_graphs, get_all_possible_graphs_fast, join_graphs_if_joint_nodes, is_segment_classified_with_only_one_class, get_segment_raw_image, get_features, add_spatial_connections_to_graphs, update_nx_graph_features

from numba.typed import List, Dict
from numba import njit, jit

import json

from networkx.algorithms.operators.all import compose_all
from scipy.stats import mode

# %%
def load_graph(file_path):
    """Load a graph from a pickle file."""
    with open(file_path, 'rb') as f:
        graph = pickle.load(f)
    return graph

def save_graph(graph, file_path):
    """Save a graph to a pickle file."""
    p = pickle.Pickler(open(file_path,"wb")) 
    p.fast = True 
    p.dump(graph)

def number_of_subfolders(path):
    count1 = 0
    for root, dirs, files in os.walk(path):
            count1 += len(dirs)

    return count1

def combine_graphs_in_folder(folder_path):
    """Combine all graphs in the folder and its subfolders, ensuring unique node labels."""
    combined_graph = nx.DiGraph()
    node_offset = 0  # To keep track of node labels across multiple graphs

    # Traverse through all subfolders inside the folder_path
    number_subfolders = number_of_subfolders(folder_path)
    count_subdirs = 0
    for subdir, _, files in os.walk(folder_path):
        count_subdirs += 1
        current_unique_node_labels = np.unique(list(nx.get_node_attributes(combined_graph, "label").values()))
        print("-- Working:", "...", subdir[-17:], "(", count_subdirs, "/", number_subfolders, ")", "Num. of nodes/edges in combined graph:", combined_graph.number_of_nodes(), combined_graph.number_of_edges(), "Unique labels in combined graph:", current_unique_node_labels)
        
        for file in files:
            if file == "graph.pickle":
                file_path = os.path.join(subdir, file)
                
                # Load the graph
                graph = load_graph(file_path)

                print("--- Number of nodes in loaded graph:", graph.number_of_nodes(), "(", file_path[-30:], ")")
                
                # Relabel the graph to avoid node label conflicts
                graph_relabel = nx.relabel_nodes(graph, lambda x, offset=node_offset: x + offset)
                
                # Update node offset to prevent overlap in the next graph
                node_offset += graph_relabel.number_of_nodes()
                
                # Compose the current graph with the combined graph
                combined_graph = nx.compose(combined_graph, graph_relabel)

    return combined_graph

def process_data_folders(base_path):
    """Process all folders under the base directory."""
    for folder in os.listdir(base_path):
        folder_path = os.path.join(base_path, folder)
        print("Working:", folder_path)
        
        if os.path.isdir(folder_path):
            # Paths for 'train' and 'val' subdirectories
            train_folder = os.path.join(folder_path, "train")
            val_folder = os.path.join(folder_path, "val")
            
            # Process and combine the graphs in 'train' folder
            if os.path.exists(train_folder):
                print("- Working:", train_folder)
                combined_train_graph = combine_graphs_in_folder(train_folder)
                save_graph(combined_train_graph, os.path.join(train_folder, "combined_graph.pickle"))
                print(f"Saved combined graph for 'train' folder: {train_folder}")
            
            # Process and combine the graphs in 'val' folder
            if os.path.exists(val_folder):
                print("- Working on:", val_folder)
                combined_val_graph = combine_graphs_in_folder(val_folder)
                save_graph(combined_val_graph, os.path.join(val_folder, "combined_graph.pickle"))
                print(f"Saved combined graph for 'val' folder: {val_folder}")

# %%
# Main function call
base_path = "./prepared_data/"
process_data_folders(base_path)
# Out:
# Working: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50
# - Working: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train
# -- Working: ... min_size_50\train ( 1 / 55 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# -- Working: ... rain\1311_3077_13 ( 2 / 55 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# --- Number of nodes in loaded graph: 113142 ( rain\1311_3077_13\graph.pickle )
# -- Working: ... rain\1417_3281_13 ( 3 / 55 ) Num. of nodes/edges in combined graph: 113142 1210313 Unique labels in combined graph: [0 2 4 5]
# --- Number of nodes in loaded graph: 110233 ( rain\1417_3281_13\graph.pickle )
# -- Working: ... rain\1487_3335_13 ( 4 / 55 ) Num. of nodes/edges in combined graph: 223375 2348419 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 122026 ( rain\1487_3335_13\graph.pickle )
# -- Working: ... rain\1700_3100_13 ( 5 / 55 ) Num. of nodes/edges in combined graph: 345401 3690675 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 117799 ( rain\1700_3100_13\graph.pickle )
# -- Working: ... rain\2006_3280_13 ( 6 / 55 ) Num. of nodes/edges in combined graph: 463200 4875756 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 113737 ( rain\2006_3280_13\graph.pickle )
# -- Working: ... rain\2029_3764_13 ( 7 / 55 ) Num. of nodes/edges in combined graph: 576937 6094946 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 118230 ( rain\2029_3764_13\graph.pickle )
# -- Working: ... rain\2065_3647_13 ( 8 / 55 ) Num. of nodes/edges in combined graph: 695167 7363596 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 124320 ( rain\2065_3647_13\graph.pickle )
# -- Working: ... rain\2235_3403_13 ( 9 / 55 ) Num. of nodes/edges in combined graph: 819487 8703260 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 119064 ( rain\2235_3403_13\graph.pickle )
# -- Working: ... rain\2415_3082_13 ( 10 / 55 ) Num. of nodes/edges in combined graph: 938551 9958064 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 114964 ( rain\2415_3082_13\graph.pickle )
# -- Working: ... rain\2459_4406_13 ( 11 / 55 ) Num. of nodes/edges in combined graph: 1053515 11207704 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 112416 ( rain\2459_4406_13\graph.pickle )
# -- Working: ... rain\2470_5030_13 ( 12 / 55 ) Num. of nodes/edges in combined graph: 1165931 12338993 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 109434 ( rain\2470_5030_13\graph.pickle )
# -- Working: ... rain\2528_4620_13 ( 13 / 55 ) Num. of nodes/edges in combined graph: 1275365 13463927 Unique labels in combined graph: [0 1 2 4 5 6]
# --- Number of nodes in loaded graph: 115444 ( rain\2528_4620_13\graph.pickle )
# -- Working: ... rain\2624_4314_13 ( 14 / 55 ) Num. of nodes/edges in combined graph: 1390809 14638955 Unique labels in combined graph: [0 1 2 3 4 5 6]
# --- Number of nodes in loaded graph: 119107 ( rain\2624_4314_13\graph.pickle )
# -- Working: ... rain\2697_3715_13 ( 15 / 55 ) Num. of nodes/edges in combined graph: 1509916 15852655 Unique labels in combined graph: [0 1 2 3 4 5 6]
# --- Number of nodes in loaded graph:
Unique labels in combined graph: [0 1 2 3 4 5 6]
# --- Number of nodes in loaded graph: 110759 ( rain\7026_3201_13\graph.pickle )
# -- Working: ... rain\7312_3008_13 ( 53 / 55 ) Num. of nodes/edges in combined graph: 5905273 61920161 Unique labels in combined graph: [0 1 2 3 4 5 6]
# --- Number of nodes in loaded graph: 111206 ( rain\7312_3008_13\graph.pickle )
# -- Working: ... rain\7367_5050_13 ( 54 / 55 ) Num. of nodes/edges in combined graph: 6016479 62991363 Unique labels in combined graph: [0 1 2 3 4 5 6]
# --- Number of nodes in loaded graph: 127463 ( rain\7367_5050_13\graph.pickle )
# -- Working: ... rain\7513_4968_13 ( 55 / 55 ) Num. of nodes/edges in combined graph: 6143942 64353753 Unique labels in combined graph: [0 1 2 3 4 5 6]
# --- Number of nodes in loaded graph: 124033 ( rain\7513_4968_13\graph.pickle )
# -- Working: ... rain\8077_5007_13 ( 56 / 55 ) Num. of nodes/edges in combined graph: 6267975 65680175 Unique labels in combined graph: [0 1 2 3 4 5 6]
# --- Number of nodes in loaded graph: 108488 ( rain\8077_5007_13\graph.pickle )
# Saved combined graph for 'train' folder: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train
# - Working on: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\val
# -- Working: ... 0_min_size_50\val ( 1 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# -- Working: ... \val\1973_3709_13 ( 2 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# --- Number of nodes in loaded graph: 113855 ( \val\1973_3709_13\graph.pickle )
# -- Working: ... \val\2569_4513_13 ( 3 / 10 ) Num. of nodes/edges in combined graph: 113855 1205219 Unique labels in combined graph: [0 2 4 5]
# --- Number of nodes in loaded graph: 113993 ( \val\2569_4513_13\graph.pickle )
# -- Working: ... \val\2789_4694_13 ( 4 / 10 ) Num. of nodes/edges in combined graph: 227848 2458667 Unique labels in combined graph: [0 2 3 4 5]
# --- Number of nodes in loaded graph: 114326 ( \val\2789_4694_13\graph.pickle )
# -- Working: ... \val\4062_3943_13 ( 5 / 10 ) Num. of nodes/edges in combined graph: 342174 3662093 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 116130 ( \val\4062_3943_13\graph.pickle )
# -- Working: ... \val\4666_2369_13 ( 6 / 10 ) Num. of nodes/edges in combined graph: 458304 4883970 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 113884 ( \val\4666_2369_13\graph.pickle )
# -- Working: ... \val\5830_3834_13 ( 7 / 10 ) Num. of nodes/edges in combined graph: 572188 6022036 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 125968 ( \val\5830_3834_13\graph.pickle )
# -- Working: ... \val\6353_3661_13 ( 8 / 10 ) Num. of nodes/edges in combined graph: 698156 7354709 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 121173 ( \val\6353_3661_13\graph.pickle )
# -- Working: ... \val\6678_3579_13 ( 9 / 10 ) Num. of nodes/edges in combined graph: 819329 8647214 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 110869 ( \val\6678_3579_13\graph.pickle )
# -- Working: ... \val\6761_3129_13 ( 10 / 10 ) Num. of nodes/edges in combined graph: 930198 9792109 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 119205 ( \val\6761_3129_13\graph.pickle )
# -- Working: ... \val\7517_4908_13 ( 11 / 10 ) Num. of nodes/edges in combined graph: 1049403 11020801 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 124423 ( \val\7517_4908_13\graph.pickle )
# Saved combined graph for 'val' folder: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\val
# Working: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50
# - Working: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train
# -- Working: ... min_size_50\train ( 1 / 15 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# -- Working: ... rain\1311_3077_13 ( 2 / 15 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# --- Number of nodes in loaded graph: 113142 ( rain\1311_3077_13\graph.pickle )
# -- Working: ... rain\1417_3281_13 ( 3 / 15 ) Num. of nodes/edges in combined graph: 113142 1210313 Unique labels in combined graph: [0 2 4 5]
# --- Number of nodes in loaded graph: 110233 ( rain\1417_3281_13\graph.pickle )
# -- Working: ... rain\1700_3100_13 ( 4 / 15 ) Num. of nodes/edges in combined graph: 223375 2348419 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 117799 ( rain\1700_3100_13\graph.pickle )
# -- Working: ... rain\2065_3647_13 ( 5 / 15 ) Num. of nodes/edges in combined graph: 341174 3533500 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 124320 ( rain\2065_3647_13\graph.pickle )
# -- Working: ... rain\2697_3715_13 ( 6 / 15 ) Num. of nodes/edges in combined graph: 465494 4873164 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 112318 ( rain\2697_3715_13\graph.pickle )
# -- Working: ... rain\3998_3016_13 ( 7 / 15 ) Num. of nodes/edges in combined graph: 577812 6033156 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 108258 ( rain\3998_3016_13\graph.pickle )
# -- Working: ... rain\4127_2991_13 ( 8 / 15 ) Num. of nodes/edges in combined graph: 686070 7178549 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 112903 ( rain\4127_2991_13\graph.pickle )
# -- Working: ... rain\4791_3920_13 ( 9 / 15 ) Num. of nodes/edges in combined graph: 798973 8340672 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 120562 ( rain\4791_3920_13\graph.pickle )
# -- Working: ... rain\4881_3344_13 ( 10 / 15 ) Num. of nodes/edges in combined graph: 919535 9655877 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 109037 ( rain\4881_3344_13\graph.pickle )
# -- Working: ... rain\5111_4560_13 ( 11 / 15 ) Num. of nodes/edges in combined graph: 1028572 10857415 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 114000 ( rain\5111_4560_13\graph.pickle )
# -- Working: ... rain\5926_3715_13 ( 12 / 15 ) Num. of nodes/edges in combined graph: 1142572 12061537 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 121447 ( rain\5926_3715_13\graph.pickle )
# -- Working: ... rain\6730_3430_13 ( 13 / 15 ) Num. of nodes/edges in combined graph: 1264019 13325274 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 112022 ( rain\6730_3430_13\graph.pickle )
# -- Working: ... rain\6824_4117_13 ( 14 / 15 ) Num. of nodes/edges in combined graph: 1376041 14509541 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 117019 ( rain\6824_4117_13\graph.pickle )
# -- Working: ... rain\7312_3008_13 ( 15 / 15 ) Num. of nodes/edges in combined graph: 1493060 15697652 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 111206 ( rain\7312_3008_13\graph.pickle )
# -- Working: ... rain\8077_5007_13 ( 16 / 15 ) Num. of nodes/edges in combined graph: 1604266 16768854 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 108488 ( rain\8077_5007_13\graph.pickle )
# Saved combined graph for 'train' folder: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train
# - Working on: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\val
# -- Working: ... 0_min_size_50\val ( 1 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# -- Working: ... \val\1973_3709_13 ( 2 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# --- Number of nodes in loaded graph: 113855 ( \val\1973_3709_13\graph.pickle )
# -- Working: ... \val\2569_4513_13 ( 3 / 10 ) Num. of nodes/edges in combined graph: 113855 1205219 Unique labels in combined graph: [0 2 4 5]
# --- Number of nodes in loaded graph: 113993 ( \val\2569_4513_13\graph.pickle )
# -- Working: ... \val\2789_4694_13 ( 4 / 10 ) Num. of nodes/edges in combined graph: 227848 2458667 Unique labels in combined graph: [0 2 3 4 5]
# --- Number of nodes in loaded graph: 114326 ( \val\2789_4694_13\graph.pickle )
# -- Working: ... \val\4062_3943_13 ( 5 / 10 ) Num. of nodes/edges in combined graph: 342174 3662093 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 116130 ( \val\4062_3943_13\graph.pickle )
# -- Working: ... \val\4666_2369_13 ( 6 / 10 ) Num. of nodes/edges in combined graph: 458304 4883970 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 113884 ( \val\4666_2369_13\graph.pickle )
# -- Working: ... \val\5830_3834_13 ( 7 / 10 ) Num. of nodes/edges in combined graph: 572188 6022036 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 125968 ( \val\5830_3834_13\graph.pickle )
# -- Working: ... \val\6353_3661_13 ( 8 / 10 ) Num. of nodes/edges in combined graph: 698156 7354709 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 121173 ( \val\6353_3661_13\graph.pickle )
# -- Working: ... \val\6678_3579_13 ( 9 / 10 ) Num. of nodes/edges in combined graph: 819329 8647214 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 110869 ( \val\6678_3579_13\graph.pickle )
# -- Working: ... \val\6761_3129_13 ( 10 / 10 ) Num. of nodes/edges in combined graph: 930198 9792109 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 119205 ( \val\6761_3129_13\graph.pickle )
# -- Working: ... \val\7517_4908_13 ( 11 / 10 ) Num. of nodes/edges in combined graph: 1049403 11020801 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 124423 ( \val\7517_4908_13\graph.pickle )
# Saved combined graph for 'val' folder: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\val
# Working: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50
# - Working: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train
# -- Working: ... min_size_50\train ( 1 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# -- Working: ... rain\1311_3077_13 ( 2 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# --- Number of nodes in loaded graph: 113142 ( rain\1311_3077_13\graph.pickle )
# -- Working: ... rain\1417_3281_13 ( 3 / 10 ) Num. of nodes/edges in combined graph: 113142 1210313 Unique labels in combined graph: [0 2 4 5]
# --- Number of nodes in loaded graph: 110233 ( rain\1417_3281_13\graph.pickle )
# -- Working: ... rain\1700_3100_13 ( 4 / 10 ) Num. of nodes/edges in combined graph: 223375 2348419 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 117799 ( rain\1700_3100_13\graph.pickle )
# -- Working: ... rain\2697_3715_13 ( 5 / 10 ) Num. of nodes/edges in combined graph: 341174 3533500 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 112318 ( rain\2697_3715_13\graph.pickle )
# -- Working: ... rain\3998_3016_13 ( 6 / 10 ) Num. of nodes/edges in combined graph: 453492 4693492 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 108258 ( rain\3998_3016_13\graph.pickle )
# -- Working: ... rain\4127_2991_13 ( 7 / 10 ) Num. of nodes/edges in combined graph: 561750 5838885 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 112903 ( rain\4127_2991_13\graph.pickle )
# -- Working: ... rain\4791_3920_13 ( 8 / 10 ) Num. of nodes/edges in combined graph: 674653 7001008 Unique labels in combined graph: [0 1 2 4 5]
# --- Number of nodes in loaded graph: 120562 ( rain\4791_3920_13\graph.pickle )
# -- Working: ... rain\6824_4117_13 ( 9 / 10 ) Num. of nodes/edges in combined graph: 795215 8316213 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 117019 ( rain\6824_4117_13\graph.pickle )
# -- Working: ... rain\7312_3008_13 ( 10 / 10 ) Num. of nodes/edges in combined graph: 912234 9504324 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 111206 ( rain\7312_3008_13\graph.pickle )
# -- Working: ... rain\8077_5007_13 ( 11 / 10 ) Num. of nodes/edges in combined graph: 1023440 10575526 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 108488 ( rain\8077_5007_13\graph.pickle )
# Saved combined graph for 'train' folder: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train
# - Working on: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\val
# -- Working: ... 0_min_size_50\val ( 1 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# -- Working: ... \val\1973_3709_13 ( 2 / 10 ) Num. of nodes/edges in combined graph: 0 0 Unique labels in combined graph: []
# --- Number of nodes in loaded graph: 113855 ( \val\1973_3709_13\graph.pickle )
# -- Working: ... \val\2569_4513_13 ( 3 / 10 ) Num. of nodes/edges in combined graph: 113855 1205219 Unique labels in combined graph: [0 2 4 5]
# --- Number of nodes in loaded graph: 113993 ( \val\2569_4513_13\graph.pickle )
# -- Working: ... \val\2789_4694_13 ( 4 / 10 ) Num. of nodes/edges in combined graph: 227848 2458667 Unique labels in combined graph: [0 2 3 4 5]
# --- Number of nodes in loaded graph: 114326 ( \val\2789_4694_13\graph.pickle )
# -- Working: ... \val\4062_3943_13 ( 5 / 10 ) Num. of nodes/edges in combined graph: 342174 3662093 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 116130 ( \val\4062_3943_13\graph.pickle )
# -- Working: ... \val\4666_2369_13 ( 6 / 10 ) Num. of nodes/edges in combined graph: 458304 4883970 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 113884 ( \val\4666_2369_13\graph.pickle )
# -- Working: ... \val\5830_3834_13 ( 7 / 10 ) Num. of nodes/edges in combined graph: 572188 6022036 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 125968 ( \val\5830_3834_13\graph.pickle )
# -- Working: ... \val\6353_3661_13 ( 8 / 10 ) Num. of nodes/edges in combined graph: 698156 7354709 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 121173 ( \val\6353_3661_13\graph.pickle )
# -- Working: ... \val\6678_3579_13 ( 9 / 10 ) Num. of nodes/edges in combined graph: 819329 8647214 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 110869 ( \val\6678_3579_13\graph.pickle )
# -- Working: ... \val\6761_3129_13 ( 10 / 10 ) Num. of nodes/edges in combined graph: 930198 9792109 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 119205 ( \val\6761_3129_13\graph.pickle )
# -- Working: ... \val\7517_4908_13 ( 11 / 10 ) Num. of nodes/edges in combined graph: 1049403 11020801 Unique labels in combined graph: [0 1 2 3 4 5]
# --- Number of nodes in loaded graph: 124423 ( \val\7517_4908_13\graph.pickle )
# Saved combined graph for 'val' folder: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\val
