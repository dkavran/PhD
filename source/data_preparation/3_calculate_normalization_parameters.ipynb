# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

from PIL import Image, ImageEnhance
import cv2

import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import torch
import math
import _pickle as pickle
import pandas as pd
import copy
import networkx as nx

from os import listdir
from os.path import isfile, join
from natsort import natsorted
from skimage.segmentation import mark_boundaries

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,15)

# Implemented imports
import sys
sys.path.append('../')
from proposed_method_lib.graph import segment_images, plot_nx_graph, save_graphs_to_file, save_item_with_pickle, load_item_with_pickle, get_indices_and_labels_for_time_frame_without_labels
from proposed_method_lib.graph_node import create_time_series_graphs, get_nx_graph, get_nx_graph_fast, get_all_possible_graphs, get_all_possible_graphs_fast, join_graphs_if_joint_nodes, is_segment_classified_with_only_one_class, get_segment_raw_image, get_features, add_spatial_connections_to_graphs, update_nx_graph_features

from numba.typed import List, Dict
from numba import njit, jit

import json

from networkx.algorithms.operators.all import compose_all
from scipy.stats import mode

# %%
def improve_path(path):
    path = os.path.abspath(path)
    if path.startswith(u"\\\\"):
            path=u"\\\\?\\UNC\\"+path[2:]
    else:
            path=u"\\\\?\\"+path
    return path

def load_graph(file_path):
    """Load a graph from a pickle file."""
    with open(file_path, 'rb') as f:
        graph = pickle.load(f)
    return graph

def save_graph(graph, file_path):
    """Save a graph to a pickle file."""
    p = pickle.Pickler(open(file_path,"wb")) 
    p.fast = True 
    p.dump(graph)

def number_of_subfolders(path):
    count1 = 0
    for root, dirs, files in os.walk(path):
            count1 += len(dirs)

    return count1

def calculate_mean_std(dataloader, num_channels, batch_size=32):
    """
    Calculate channel-wise mean and standard deviation for a dataset.
    Args:
        dataset (Dataset): PyTorch dataset (train dataset).
        batch_size (int): Batch size for DataLoader.
    Returns:
        tuple: mean and standard deviation (each as a list of 3 values for RGB).
    """
    mean = torch.zeros(num_channels)
    std = torch.zeros(num_channels)
    n_samples = 0

    for images, _ in dataloader:  # Assuming dataset returns (image, label)
        # Flatten the images to (batch_size, channels, -1) and compute statistics
        images = images.view(images.size(0), images.size(1), -1)
        mean += images.mean(dim=[0, 2]) * images.size(0)
        std += images.std(dim=[0, 2]) * images.size(0)
        n_samples += images.size(0)

    mean /= n_samples
    std /= n_samples

    return mean.tolist(), std.tolist()

def process_data_folders(base_path):
    """Process all folders under the base directory."""
    
    for folder in os.listdir(base_path):
        folder_path = os.path.join(base_path, folder)
        print("Working:", folder_path)

        mean = np.zeros(4, dtype=np.float32)
        std = np.zeros(4, dtype=np.float32)
        n_samples = 0
        
        if os.path.isdir(folder_path):
            # Paths for 'train' and 'val' subdirectories
            train_folder = os.path.join(folder_path, "train")
            
            # Process and combine the graphs in 'train' folder
            if os.path.exists(train_folder):
                for subdir, _, files in os.walk(train_folder):
                    if subdir != train_folder:
                        print("-- Working on subdirectory:", subdir)
                        current_folder_original_data_path = "E:\PhD\prepared_dynamic_earth_net_data/train/" + subdir.split("\\")[-1] + "/image"
                        file_names = [f for f in listdir(current_folder_original_data_path) if isfile(join(current_folder_original_data_path, f))]

                        for file_name in file_names:
                            raw_image = np.load(current_folder_original_data_path + "/" + file_name)

                            mean += np.mean(raw_image, axis=(0,1))
                            std += np.std(raw_image, axis=(0,1))
                            n_samples += 1

                            
        # Calculate means and stds
        mean /= n_samples
        std /= n_samples

        # File path
        json_file_path = os.path.join(folder_path, "train_set_normalization_data.json")
        
        # Create the dictionary
        normalization_data = {
            "means": {
                "R": str(mean[0]),
                "G": str(mean[1]),
                "B": str(mean[2]),
                "infra": str(mean[3])
            },
            "stds": {
                "R": str(std[0]),
                "G": str(std[1]),
                "B": str(std[2]),
                "infra": str(std[3])
            }
        }
        
        # Save to JSON file
        with open(json_file_path, "w") as json_file:
            json.dump(normalization_data, json_file, indent=4)
        
        print(f"JSON file saved at: {json_file_path}")

# %%
# Main function call
base_path = "./prepared_data/"
process_data_folders(base_path)
# Out:
# Working: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1311_3077_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1417_3281_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1487_3335_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1700_3100_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2006_3280_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2029_3764_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2065_3647_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2235_3403_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2415_3082_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2459_4406_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2470_5030_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2528_4620_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2624_4314_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2697_3715_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2832_4366_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2850_4139_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\3002_4273_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\3998_3016_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4127_2991_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4169_3944_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4223_3246_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4240_3972_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4254_2915_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4397_4302_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4421_3800_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4426_3835_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4622_3159_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4768_4131_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4780_3377_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4791_3920_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4806_3588_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4838_3506_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4856_4087_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4881_3344_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\5111_4560_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\5125_4049_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\5863_3800_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\5926_3715_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\5989_3554_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6204_3495_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6381_3681_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6466_3380_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6468_3360_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6475_3361_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6688_3456_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6730_3430_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6752_3115_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6810_3478_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6813_3313_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6824_4117_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\7026_3201_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\7312_3008_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\7367_5050_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\7513_4968_13
# -- Working on subdirectory: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\8077_5007_13
# JSON file saved at: ./prepared_data/interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train_set_normalization_data.json
# Working: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1311_3077_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1417_3281_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1700_3100_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2065_3647_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2697_3715_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\3998_3016_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4127_2991_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4791_3920_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4881_3344_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\5111_4560_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\5926_3715_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6730_3430_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6824_4117_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\7312_3008_13
# -- Working on subdirectory: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\8077_5007_13
# JSON file saved at: ./prepared_data/my2_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train_set_normalization_data.json
# Working: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1311_3077_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1417_3281_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\1700_3100_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\2697_3715_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\3998_3016_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4127_2991_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\4791_3920_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\6824_4117_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\7312_3008_13
# -- Working on subdirectory: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train\8077_5007_13
# JSON file saved at: ./prepared_data/my_interval_monthly_padding_32_bbox_size_32_layers_rgb_plus_infrared_sc_10_sigma_1.0_min_size_50\train_set_normalization_data.json
